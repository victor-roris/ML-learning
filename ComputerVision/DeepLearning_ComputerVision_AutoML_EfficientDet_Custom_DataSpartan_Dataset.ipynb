# %% [markdown]
# <a href="https://colab.research.google.com/github/victor-roris/ML-learning/blob/master/ComputerVision/DeepLearning_ComputerVision_AutoML_EfficientDet_Custom_DataSpartan_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EfficientDet - Custom DataSpartan dataset
#
# Notebook to train a EfficientDet model ([link](https://github.com/google/automl/tree/master/efficientdet)) with custom dataset generated in the AIDocs project of DataSpartan. This dataset is about document segmentation and it is accesible from my profesional drive account (this is private and not public available).
#
# This notebook is an adaptation from: [tutorial notebooks 1](https://github.com/google/automl/blob/master/efficientdet/tutorial.ipynb)
#
# [github](https://github.com/google/automl/tree/master/efficientdet)

# %%
from IPython.display import Image, clear_output  # to display images

# %% [markdown]
# ## Install EfficientDet

# %%
# %%capture
#@title
import os
import sys
import tensorflow.compat.v1 as tf

# Download source code.
if "efficientdet" not in os.getcwd():

  # Clone the efficientdet project
  # !git clone --depth 1 https://github.com/google/automl

  # Modify console working path to the efficientdet root folder
  os.chdir('automl/efficientdet')       
  sys.path.append('.')            

  # Install requirements
  # !pip install -r requirements.txt
  # !pip install -U 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
else:
  # !git pull

# %% [markdown]
# ## Download dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Export dataset filepath
dataset_folderpath = "/content/dataset/"

# %%
# !rm -R {dataset_folderpath}
# Out:
# rm: cannot remove '/content/dataset/': No such file or directory

# %%
from pathlib import Path
def mkdir(sfolderpath):
  folderpath = Path(sfolderpath)
  folderpath.mkdir(parents=True, exist_ok=True)

mkdir(dataset_folderpath)

# %%
# !tar -xvf /content/drive/My\ Drive/DATASPARTAN/PROYECTOS/AI-DOCUMENTS/SEGMENTATION/export..segmentation..2020.10.05.tar.gz -C {dataset_folderpath}

clear_output()

# !ls {dataset_folderpath}
# Out:
# export_coco.json  segmentation	  yolo_data.yaml
# image		  sub_annotation  yolo_labels

# %% [markdown]
# ## Train

# %% [markdown]
# ### Convert dataset to tfrecord
#
# https://github.com/google/automl/tree/master/efficientdet/dataset

# %%
# !rm tfrecord -R
# Out:
# rm: cannot remove 'tfrecord': No such file or directory

# %%
# !mkdir tfrecord
# !PYTHONPATH=".:$PYTHONPATH"  python dataset/create_coco_tfrecord.py  \
  --image_dir=/content/dataset/image/ \
  --image_info_file=/content/dataset/export_coco.json \
  --object_annotations_file=/content/dataset/export_coco.json \
  --output_file_prefix=tfrecord/ds --num_shards=100
# Out:
# 2020-10-07 15:44:30.371348: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# I1007 15:44:32.027569 140179327129472 create_coco_tfrecord.py:285] writing to output path: tfrecord/ds
# I1007 15:44:35.018472 140179327129472 create_coco_tfrecord.py:215] Building bounding box index.
# I1007 15:44:35.034357 140179327129472 create_coco_tfrecord.py:226] 25 images are missing bboxes.
# I1007 15:44:35.106595 140179327129472 create_coco_tfrecord.py:323] On image 0 of 3968
# I1007 15:44:35.358397 140179327129472 create_coco_tfrecord.py:323] On image 100 of 3968
# I1007 15:44:35.583385 140179327129472 create_coco_tfrecord.py:323] On image 200 of 3968
# I1007 15:44:35.833041 140179327129472 create_coco_tfrecord.py:323] On image 300 of 3968
# I1007 15:44:36.055526 140179327129472 create_coco_tfrecord.py:323] On image 400 of 3968
# I1007 15:44:36.390229 140179327129472 create_coco_tfrecord.py:323] On image 500 of 3968
# I1007 15:44:36.635937 140179327129472 create_coco_tfrecord.py:323] On image 600 of 3968
# I1007 15:44:36.890361 140179327129472 create_coco_tfrecord.py:323] On image 700 of 3968
# I1007 15:44:37.161734 140179327129472 create_coco_tfrecord.py:323] On image 800 of 3968
# I1007 15:44:37.388989 140179327129472 create_coco_tfrecord.py:323] On image 900 of 3968
# I1007 15:44:37.701877 140179327129472 create_coco_tfrecord.py:323] On image 1000 of 3968
# I1007 15:44:37.959526 140179327129472 create_coco_tfrecord.py:323] On image 1100 of 3968
# I1007 15:44:38.182829 140179327129472 create_coco_tfrecord.py:323] On image 1200 of 3968
# I1007 15:44:38.413909 140179327129472 create_coco_tfrecord.py:323] On image 1300 of 3968
# I1007 15:44:38.659841 140179327129472 create_coco_tfrecord.py:323] On image 1400 of 3968
# I1007 15:44:38.894215 140179327129472 create_coco_tfrecord.py:323] On image 1500 of 3968
# I1007 15:44:39.245966 140179327129472 create_coco_tfrecord.py:323] On image 1600 of 3968
# I1007 15:44:39.499300 140179327129472 create_coco_tfrecord.py:323] On image 1700 of 3968
# I1007 15:44:39.765061 140179327129472 create_coco_tfrecord.py:323] On image 1800 of 3968
# I1007 15:44:40.025545 140179327129472 create_coco_tfrecord.py:323] On image 1900 of 3968
# I1007 15:44:40.262701 140179327129472 create_coco_tfrecord.py:323] On image 2000 of 3968
# I1007 15:44:40.503825 140179327129472 create_coco_tfrecord.py:323] On image 2100 of 3968
# I1007 15:44:40.715476 140179327129472 create_coco_tfrecord.py:323] On image 2200 of 3968
# I1007 15:44:40.935841 140179327129472 create_coco_tfrecord.py:323] On image 2300 of 3968
# I1007 15:44:41.297632 140179327129472 create_coco_tfrecord.py:323] On image 2400 of 3968
# I1007 15:44:41.989772 140179327129472 create_coco_tfrecord.py:323] On image 2500 of 3968
# I1007 15:44:42.685644 140179327129472 create_coco_tfrecord.py:323] On image 2600 of 3968
# I1007 15:44:43.447272 140179327129472 create_coco_tfrecord.py:323] On image 2700 of 3968
# I1007 15:44:44.492678 140179327129472 create_coco_tfrecord.py:323] On image 2800 of 3968
# I1007 15:44:45.197554 140179327129472 create_coco_tfrecord.py:323] On image 2900 of 3968
# I1007 15:44:46.260476 140179327129472 create_coco_tfrecord.py:323] On image 3000 of 3968
# I1007 15:44:46.414587 140179327129472 create_coco_tfrecord.py:323] On image 3100 of 3968
# I1007 15:44:46.785754 140179327129472 create_coco_tfrecord.py:323] On image 3200 of 3968
# I1007 15:44:47.228224 140179327129472 create_coco_tfrecord.py:323] On image 3300 of 3968
# I1007 15:44:47.767150 140179327129472 create_coco_tfrecord.py:323] On image 3400 of 3968
# I1007 15:44:48.425507 140179327129472 create_coco_tfrecord.py:323] On image 3500 of 3968
# I1007 15:44:49.377631 140179327129472 create_coco_tfrecord.py:323] On image 3600 of 3968
# I1007 15:44:50.299725 140179327129472 create_coco_tfrecord.py:323] On image 3700 of 3968
# I1007 15:44:51.042284 140179327129472 create_coco_tfrecord.py:323] On image 3800 of 3968
# I1007 15:44:51.211537 140179327129472 create_coco_tfrecord.py:323] On image 3900 of 3968
# I1007 15:44:51.278689 140179327129472 create_coco_tfrecord.py:335] Finished writing, skipped 0 annotations.

# %% [markdown]
# We calculate the number of images per epoch

# %%
# We users should use all shards ds-*-of-00100.tfrecord.
file_pattern = 'ds-*-of-00100.tfrecord' 
# file_pattern = 'ds-00000-of-00100.tfrecord' 
images_per_epoch = 57 * len(tf.io.gfile.glob('tfrecord/' + file_pattern))
images_per_epoch = images_per_epoch // 8 * 8  # round to 64.
print('images_per_epoch = {}'.format(images_per_epoch))
# Out:
# images_per_epoch = 5696

# %% [markdown]
# ## Training

# %%
MODEL = 'efficientdet-d0'

# %%
# Train efficientdet from scratch with backbone checkpoint.
backbone_name = {
    'efficientdet-d0': 'efficientnet-b0',
    'efficientdet-d1': 'efficientnet-b1',
    'efficientdet-d2': 'efficientnet-b2',
    'efficientdet-d3': 'efficientnet-b3',
    'efficientdet-d4': 'efficientnet-b4',
    'efficientdet-d5': 'efficientnet-b5',
    'efficientdet-d6': 'efficientnet-b6',
    'efficientdet-d7': 'efficientnet-b6',
}[MODEL]


# generating train tfrecord is large, so we skip the execution here.
import os
if backbone_name not in os.listdir():
  # !wget https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/ckptsaug/{backbone_name}.tar.gz
  # !tar xf {backbone_name}.tar.gz

# !rm /tmp/model_dir -R
# !mkdir /tmp/model_dir
# key option: use --backbone_ckpt rather than --ckpt.
# Don't use ema since we only train a few steps.
# !python main.py --mode=train_and_eval \
    --training_file_pattern=tfrecord/{file_pattern} \
    --validation_file_pattern=tfrecord/{file_pattern} \
    --model_name={MODEL} \
    --model_dir=/tmp/model_dir/{MODEL}-scratch  \
    --backbone_ckpt={backbone_name} \
    --train_batch_size=4 \
    --eval_batch_size=4 --eval_samples={images_per_epoch}  \
    --num_examples_per_epoch={images_per_epoch}  --num_epochs=1  \
    --hparams="num_classes=6,moving_average_decay=0,mixed_precision=true,max_instances_per_image=1000"
# Out:
# --2020-10-07 15:45:00--  https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/ckptsaug/efficientnet-b0.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 64.233.189.128, 108.177.97.128, 108.177.125.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|64.233.189.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39302973 (37M) [application/gzip]
# Saving to: ‘efficientnet-b0.tar.gz’
#
# efficientnet-b0.tar 100%[===================>]  37.48M  54.9MB/s    in 0.7s
#
# 2020-10-07 15:45:01 (54.9 MB/s) - ‘efficientnet-b0.tar.gz’ saved [39302973/39302973]
#
# rm: cannot remove '/tmp/model_dir': No such file or directory
# 2020-10-07 15:45:02.871415: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# I1007 15:45:05.011347 140371753760640 main.py:228] {'name': 'efficientdet-d0', 'act_type': 'swish', 'image_size': (512, 512), 'target_size': None, 'input_rand_hflip': True, 'jitter_min': 0.1, 'jitter_max': 2.0, 'autoaugment_policy': None, 'use_augmix': False, 'augmix_params': [3, -1, 1], 'sample_image': None, 'num_classes': 6, 'seg_num_classes': 3, 'heads': ['object_detection'], 'skip_crowd_during_training': True, 'label_map': None, 'max_instances_per_image': 1000, 'regenerate_source_id': False, 'min_level': 3, 'max_level': 7, 'num_scales': 3, 'aspect_ratios': [1.0, 2.0, 0.5], 'anchor_scale': 4.0, 'is_training_bn': True, 'momentum': 0.9, 'optimizer': 'sgd', 'learning_rate': 0.08, 'lr_warmup_init': 0.008, 'lr_warmup_epoch': 1.0, 'first_lr_drop_epoch': 200.0, 'second_lr_drop_epoch': 250.0, 'poly_lr_power': 0.9, 'clip_gradients_norm': 10.0, 'num_epochs': 1, 'data_format': 'channels_last', 'label_smoothing': 0.0, 'alpha': 0.25, 'gamma': 1.5, 'delta': 0.1, 'box_loss_weight': 50.0, 'iou_loss_type': None, 'iou_loss_weight': 1.0, 'weight_decay': 4e-05, 'strategy': None, 'mixed_precision': True, 'box_class_repeats': 3, 'fpn_cell_repeats': 3, 'fpn_num_filters': 64, 'separable_conv': True, 'apply_bn_for_resampling': True, 'conv_after_downsample': False, 'conv_bn_act_pattern': False, 'drop_remainder': True, 'nms_configs': {'method': 'gaussian', 'iou_thresh': None, 'score_thresh': None, 'sigma': None, 'max_nms_inputs': 0, 'max_output_size': 100}, 'fpn_name': None, 'fpn_weight_method': None, 'fpn_config': None, 'survival_prob': None, 'img_summary_steps': None, 'lr_decay_method': 'cosine', 'moving_average_decay': 0, 'ckpt_var_scope': None, 'skip_mismatch': True, 'backbone_name': 'efficientnet-b0', 'backbone_config': None, 'var_freeze_expr': None, 'use_keras_model': True, 'dataset_type': None, 'positives_momentum': None, 'device': {'grad_ckpting': False, 'grad_ckpting_list': ['Add_', 'AddN'], 'nvgpu_logging': False}, 'model_name': 'efficientdet-d0', 'iterations_per_loop': 100, 'model_dir': '/tmp/model_dir/efficientdet-d0-scratch', 'num_shards': 8, 'num_examples_per_epoch': 5696, 'backbone_ckpt': 'efficientnet-b0', 'ckpt': None, 'val_json_file': None, 'testdev_dir': None, 'profile': False, 'mode': 'train_and_eval'}
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/model_dir/efficientdet-d0-scratch', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I1007 15:45:05.110216 140371753760640 estimator.py:191] Using config: {'_model_dir': '/tmp/model_dir/efficientdet-d0-scratch', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/model_dir/efficientdet-d0-scratch', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I1007 15:45:05.111691 140371753760640 estimator.py:191] Using config: {'_model_dir': '/tmp/model_dir/efficientdet-d0-scratch', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 100, '_save_checkpoints_secs': None, '_session_config': allow_soft_placement: true
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_experimental_max_worker_delay_secs': None, '_session_creation_timeout_secs': 7200, '_service': None, '_cluster_spec': ClusterSpec({}), '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# I1007 15:45:05.112295 140371753760640 main.py:336] Folder /tmp/model_dir/efficientdet-d0-scratch has no ckpt with valid step.
#
#    =====> Starting training, epoch: 1.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# W1007 15:45:05.146331 140371753760640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2020-10-07 15:45:05.169740: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-07 15:45:05.228441: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:05.229465: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 15:45:05.229534: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 15:45:05.472760: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 15:45:05.598946: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 15:45:05.637562: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 15:45:05.891396: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 15:45:05.938534: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 15:45:06.458639: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 15:45:06.458865: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:06.459733: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:06.460495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# I1007 15:45:06.836451 140371753760640 dataloader.py:83] target_size = (512, 512), output_size = (512, 512)
# INFO:tensorflow:Calling model_fn.
# I1007 15:45:07.332824 140371753760640 estimator.py:1162] Calling model_fn.
# I1007 15:45:07.333335 140371753760640 utils.py:585] use mixed precision policy name mixed_float16
# 2020-10-07 15:45:07.342014: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# WARNING:tensorflow:Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   Tesla K80, compute capability 3.7
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# W1007 15:45:07.343247 140371753760640 device_compatibility_check.py:111] Mixed precision compatibility check (mixed_float16): WARNING
# Your GPU may run slowly with dtype policy mixed_float16 because it does not have compute capability of at least 7.0. Your GPU:
#   Tesla K80, compute capability 3.7
# See https://developer.nvidia.com/cuda-gpus for a list of GPUs and their compute capabilities.
# If you will use compatible GPU(s) not attached to this host, e.g. by running a multi-worker model, you can ignore this warning. This message will only be logged once
# I1007 15:45:07.354178 140371753760640 efficientnet_builder.py:215] global_params= GlobalParams(batch_norm_momentum=0.99, batch_norm_epsilon=0.001, dropout_rate=0.2, data_format='channels_last', num_classes=1000, width_coefficient=1.0, depth_coefficient=1.0, depth_divisor=8, min_depth=None, survival_prob=0.0, relu_fn=functools.partial(<function activation_fn at 0x7faa90b82488>, act_type='swish'), batch_norm=<class 'utils.BatchNormalization'>, use_se=True, local_pooling=None, condconv_num_experts=None, clip_projection_output=False, blocks_args=['r1_k3_s11_e1_i32_o16_se0.25', 'r2_k3_s22_e6_i16_o24_se0.25', 'r2_k5_s22_e6_i24_o40_se0.25', 'r3_k3_s22_e6_i40_o80_se0.25', 'r3_k5_s11_e6_i80_o112_se0.25', 'r4_k5_s22_e6_i112_o192_se0.25', 'r1_k3_s11_e6_i192_o320_se0.25'], fix_head_stem=None)
# I1007 15:45:07.670098 140371753760640 efficientdet_keras.py:682] fnode 0 : {'feat_level': 6, 'inputs_offsets': [3, 4]}
# I1007 15:45:07.671186 140371753760640 efficientdet_keras.py:682] fnode 1 : {'feat_level': 5, 'inputs_offsets': [2, 5]}
# I1007 15:45:07.672181 140371753760640 efficientdet_keras.py:682] fnode 2 : {'feat_level': 4, 'inputs_offsets': [1, 6]}
# I1007 15:45:07.673416 140371753760640 efficientdet_keras.py:682] fnode 3 : {'feat_level': 3, 'inputs_offsets': [0, 7]}
# I1007 15:45:07.674453 140371753760640 efficientdet_keras.py:682] fnode 4 : {'feat_level': 4, 'inputs_offsets': [1, 7, 8]}
# I1007 15:45:07.675561 140371753760640 efficientdet_keras.py:682] fnode 5 : {'feat_level': 5, 'inputs_offsets': [2, 6, 9]}
# I1007 15:45:07.676665 140371753760640 efficientdet_keras.py:682] fnode 6 : {'feat_level': 6, 'inputs_offsets': [3, 5, 10]}
# I1007 15:45:07.677695 140371753760640 efficientdet_keras.py:682] fnode 7 : {'feat_level': 7, 'inputs_offsets': [4, 11]}
# I1007 15:45:07.679331 140371753760640 efficientdet_keras.py:682] fnode 0 : {'feat_level': 6, 'inputs_offsets': [3, 4]}
# I1007 15:45:07.680345 140371753760640 efficientdet_keras.py:682] fnode 1 : {'feat_level': 5, 'inputs_offsets': [2, 5]}
# I1007 15:45:07.681357 140371753760640 efficientdet_keras.py:682] fnode 2 : {'feat_level': 4, 'inputs_offsets': [1, 6]}
# I1007 15:45:07.682349 140371753760640 efficientdet_keras.py:682] fnode 3 : {'feat_level': 3, 'inputs_offsets': [0, 7]}
# I1007 15:45:07.683397 140371753760640 efficientdet_keras.py:682] fnode 4 : {'feat_level': 4, 'inputs_offsets': [1, 7, 8]}
# I1007 15:45:07.684454 140371753760640 efficientdet_keras.py:682] fnode 5 : {'feat_level': 5, 'inputs_offsets': [2, 6, 9]}
# I1007 15:45:07.685465 140371753760640 efficientdet_keras.py:682] fnode 6 : {'feat_level': 6, 'inputs_offsets': [3, 5, 10]}
# I1007 15:45:07.686451 140371753760640 efficientdet_keras.py:682] fnode 7 : {'feat_level': 7, 'inputs_offsets': [4, 11]}
# I1007 15:45:07.688194 140371753760640 efficientdet_keras.py:682] fnode 0 : {'feat_level': 6, 'inputs_offsets': [3, 4]}
# I1007 15:45:07.689196 140371753760640 efficientdet_keras.py:682] fnode 1 : {'feat_level': 5, 'inputs_offsets': [2, 5]}
# I1007 15:45:07.690251 140371753760640 efficientdet_keras.py:682] fnode 2 : {'feat_level': 4, 'inputs_offsets': [1, 6]}
# I1007 15:45:07.691424 140371753760640 efficientdet_keras.py:682] fnode 3 : {'feat_level': 3, 'inputs_offsets': [0, 7]}
# I1007 15:45:07.692398 140371753760640 efficientdet_keras.py:682] fnode 4 : {'feat_level': 4, 'inputs_offsets': [1, 7, 8]}
140371753760640 efficientnet_model.py:195] Built SE se : (4, 1, 1, 1152)
# I1007 15:45:10.248689 140371753760640 efficientnet_model.py:412] Project shape: (4, 16, 16, 320)
# I1007 15:45:13.980054 140371753760640 utils.py:585] use mixed precision policy name float32
# I1007 15:45:13.980426 140371753760640 det_model_fn.py:76] LR schedule method: cosine
# I1007 15:45:14.317444 140371753760640 utils.py:361] Adding scale summary ('lrn_rate', <tf.Tensor 'Select:0' shape=() dtype=float32>)
# I1007 15:45:14.319707 140371753760640 utils.py:361] Adding scale summary ('trainloss/cls_loss', <tf.Tensor 'AddN:0' shape=() dtype=float32>)
# I1007 15:45:14.321610 140371753760640 utils.py:361] Adding scale summary ('trainloss/box_loss', <tf.Tensor 'AddN_1:0' shape=() dtype=float32>)
# I1007 15:45:14.323454 140371753760640 utils.py:361] Adding scale summary ('trainloss/det_loss', <tf.Tensor 'add_4:0' shape=() dtype=float32>)
# I1007 15:45:14.325431 140371753760640 utils.py:361] Adding scale summary ('trainloss/reg_l2_loss', <tf.Tensor 'mul_14:0' shape=() dtype=float32>)
# I1007 15:45:14.327351 140371753760640 utils.py:361] Adding scale summary ('trainloss/loss', <tf.Tensor 'add_5:0' shape=() dtype=float32>)
# I1007 15:45:14.331117 140371753760640 utils.py:361] Adding scale summary ('train_epochs', <tf.Tensor 'truediv_7:0' shape=() dtype=float32>)
# I1007 15:45:14.333309 140371753760640 det_model_fn.py:436] clip gradients norm by 10.000000
# I1007 15:45:24.854966 140371753760640 utils.py:361] Adding scale summary ('gradient_norm', <tf.Tensor 'clip/global_norm_1/global_norm:0' shape=() dtype=float32>)
# I1007 15:45:27.417759 140371753760640 det_model_fn.py:578] restore variables from efficientnet-b0
# I1007 15:45:27.417960 140371753760640 utils.py:99] Init model from checkpoint efficientnet-b0
# I1007 15:45:27.424082 140371753760640 utils.py:142] Init efficientnet-b0/stem/conv2d/kernel from ckpt var efficientnet-b0/stem/conv2d/kernel
# I1007 15:45:27.424231 140371753760640 utils.py:142] Init efficientnet-b0/stem/tpu_batch_normalization/gamma from ckpt var efficientnet-b0/stem/tpu_batch_normalization/gamma
# I1007 15:45:27.424355 140371753760640 utils.py:142] Init efficientnet-b0/stem/tpu_batch_normalization/beta from ckpt var efficientnet-b0/stem/tpu_batch_normalization/beta
# I1007 15:45:27.424472 140371753760640 utils.py:142] Init efficientnet-b0/stem/tpu_batch_normalization/moving_mean from ckpt var efficientnet-b0/stem/tpu_batch_normalization/moving_mean
# I1007 15:45:27.424605 140371753760640 utils.py:142] Init efficientnet-b0/stem/tpu_batch_normalization/moving_variance from ckpt var efficientnet-b0/stem/tpu_batch_normalization/moving_variance
# INFO:tensorflow:Done calling model_fn.
# I1007 15:45:28.321074 140371753760640 estimator.py:1164] Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# I1007 15:45:28.322400 140371753760640 basic_session_run_hooks.py:546] Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# I1007 15:45:33.545937 140371753760640 monitored_session.py:246] Graph was finalized.
# 2020-10-07 15:45:33.561398: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-07 15:45:33.561681: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1367800 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 15:45:33.561718: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-07 15:45:33.641624: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:33.642546: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1367640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 15:45:33.642581: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-10-07 15:45:33.643708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:33.644491: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 15:45:33.644548: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 15:45:33.644604: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 15:45:33.644644: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 15:45:33.644686: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 15:45:33.644730: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 15:45:33.644765: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 15:45:33.644802: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 15:45:33.644889: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:33.645648: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:33.646386: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-07 15:45:33.650236: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 15:45:37.485286: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-07 15:45:37.485342: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-07 15:45:37.485361: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-07 15:45:37.485615: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:37.486384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:45:37.487115: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-07 15:45:37.487172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10630 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Running local_init_op.
# I1007 15:45:41.257992 140371753760640 session_manager.py:505] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1007 15:45:41.432235 140371753760640 session_manager.py:508] Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# I1007 15:45:54.789966 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:45:54.790871 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 0 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# I1007 15:45:57.821809 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 0...
# 2020-10-07 15:46:10.462211: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 15:46:14.649010: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# INFO:tensorflow:loss = 2.5619686, step = 0
# I1007 15:46:38.437362 140371753760640 basic_session_run_hooks.py:262] loss = 2.5619686, step = 0
# INFO:tensorflow:box_loss = 0.015782852, cls_loss = 1.1702211, det_loss = 1.9593637, step = 0
# I1007 15:46:38.437857 140371753760640 basic_session_run_hooks.py:262] box_loss = 0.015782852, cls_loss = 1.1702211, det_loss = 1.9593637, step = 0
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 100...
# I1007 15:47:33.720520 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 100...
# INFO:tensorflow:Saving checkpoints for 100 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:47:33.720826 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 100 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 100...
# I1007 15:47:35.837893 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 100...
# INFO:tensorflow:global_step/sec: 1.72969
# I1007 15:47:36.250232 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 1.72969
# INFO:tensorflow:loss = 2.377495, step = 100 (57.814 sec)
# I1007 15:47:36.251375 140371753760640 basic_session_run_hooks.py:260] loss = 2.377495, step = 100 (57.814 sec)
# INFO:tensorflow:box_loss = 0.013477944, cls_loss = 1.1012442, det_loss = 1.7751415, step = 100 (57.814 sec)
# I1007 15:47:36.251763 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.013477944, cls_loss = 1.1012442, det_loss = 1.7751415, step = 100 (57.814 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 200...
# I1007 15:48:20.421855 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 200...
# INFO:tensorflow:Saving checkpoints for 200 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:48:20.422144 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 200 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 200...
# I1007 15:48:22.533174 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 200...
# INFO:tensorflow:global_step/sec: 2.14089
# I1007 15:48:22.959642 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.14089
# INFO:tensorflow:loss = 2.2539215, step = 200 (46.709 sec)
# I1007 15:48:22.960757 140371753760640 basic_session_run_hooks.py:260] loss = 2.2539215, step = 200 (46.709 sec)
# INFO:tensorflow:box_loss = 0.014565686, cls_loss = 0.9234512, det_loss = 1.6517354, step = 200 (46.709 sec)
# I1007 15:48:22.961115 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.014565686, cls_loss = 0.9234512, det_loss = 1.6517354, step = 200 (46.709 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 300...
# I1007 15:49:07.216599 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 300...
# INFO:tensorflow:Saving checkpoints for 300 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:49:07.216857 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 300 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 300...
# I1007 15:49:09.230461 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 300...
# INFO:tensorflow:global_step/sec: 2.13813
# I1007 15:49:09.729477 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.13813
# INFO:tensorflow:loss = 1.9559267, step = 300 (46.770 sec)
# I1007 15:49:09.730550 140371753760640 basic_session_run_hooks.py:260] loss = 1.9559267, step = 300 (46.770 sec)
# INFO:tensorflow:box_loss = 0.010136838, cls_loss = 0.84713745, det_loss = 1.3539793, step = 300 (46.770 sec)
# I1007 15:49:09.730778 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.010136838, cls_loss = 0.84713745, det_loss = 1.3539793, step = 300 (46.770 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 400...
# I1007 15:49:53.836833 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 400...
# INFO:tensorflow:Saving checkpoints for 400 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:49:53.837185 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 400 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 400...
# I1007 15:49:55.853009 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 400...
# INFO:tensorflow:global_step/sec: 2.14586
# I1007 15:49:56.330827 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.14586
# INFO:tensorflow:loss = 1.8419586, step = 400 (46.602 sec)
# I1007 15:49:56.332261 140371753760640 basic_session_run_hooks.py:260] loss = 1.8419586, step = 400 (46.602 sec)
# INFO:tensorflow:box_loss = 0.0108862715, cls_loss = 0.69595957, det_loss = 1.2402731, step = 400 (46.602 sec)
# I1007 15:49:56.332586 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.0108862715, cls_loss = 0.69595957, det_loss = 1.2402731, step = 400 (46.602 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 500...
# I1007 15:50:40.778665 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 500...
# INFO:tensorflow:Saving checkpoints for 500 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:50:40.778978 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 500 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:971: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# W1007 15:50:40.859236 140371753760640 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/training/saver.py:971: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 500...
# I1007 15:50:42.855251 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 500...
# INFO:tensorflow:global_step/sec: 2.13029
# I1007 15:50:43.272815 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.13029
# INFO:tensorflow:loss = 1.7317617, step = 500 (46.942 sec)
# I1007 15:50:43.273833 140371753760640 basic_session_run_hooks.py:260] loss = 1.7317617, step = 500 (46.942 sec)
# INFO:tensorflow:box_loss = 0.009106873, cls_loss = 0.67500913, det_loss = 1.1303527, step = 500 (46.942 sec)
# I1007 15:50:43.274232 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.009106873, cls_loss = 0.67500913, det_loss = 1.1303527, step = 500 (46.942 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 600...
# I1007 15:51:27.616896 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 600...
# INFO:tensorflow:Saving checkpoints for 600 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:51:27.617192 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 600 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 600...
# I1007 15:51:29.689539 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 600...
# INFO:tensorflow:global_step/sec: 2.13064
# I1007 15:51:30.207184 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.13064
# INFO:tensorflow:loss = 1.7780318, step = 600 (46.935 sec)
# I1007 15:51:30.208395 140371753760640 basic_session_run_hooks.py:260] loss = 1.7780318, step = 600 (46.935 sec)
# INFO:tensorflow:box_loss = 0.010168091, cls_loss = 0.66848755, det_loss = 1.176892, step = 600 (46.935 sec)
# I1007 15:51:30.208784 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.010168091, cls_loss = 0.66848755, det_loss = 1.176892, step = 600 (46.935 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 700...
# I1007 15:52:14.785154 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 700...
# INFO:tensorflow:Saving checkpoints for 700 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:52:14.785461 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 700 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 700...
# I1007 15:52:16.872172 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 700...
# INFO:tensorflow:global_step/sec: 2.12034
# I1007 15:52:17.369461 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.12034
# INFO:tensorflow:loss = 2.0946884, step = 700 (47.162 sec)
# I1007 15:52:17.370555 140371753760640 basic_session_run_hooks.py:260] loss = 2.0946884, step = 700 (47.162 sec)
# INFO:tensorflow:box_loss = 0.014720167, cls_loss = 0.7578068, det_loss = 1.4938152, step = 700 (47.162 sec)
# I1007 15:52:17.370907 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.014720167, cls_loss = 0.7578068, det_loss = 1.4938152, step = 700 (47.162 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 800...
# I1007 15:53:02.173452 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 800...
# INFO:tensorflow:Saving checkpoints for 800 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:53:02.173735 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 800 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 800...
# I1007 15:53:04.238464 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 800...
# INFO:tensorflow:global_step/sec: 2.11459
# I1007 15:53:04.659930 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.11459
# INFO:tensorflow:loss = 1.8543074, step = 800 (47.291 sec)
# I1007 15:53:04.661345 140371753760640 basic_session_run_hooks.py:260] loss = 1.8543074, step = 800 (47.291 sec)
# INFO:tensorflow:box_loss = 0.010927252, cls_loss = 0.7073262, det_loss = 1.2536888, step = 800 (47.291 sec)
# I1007 15:53:04.661658 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.010927252, cls_loss = 0.7073262, det_loss = 1.2536888, step = 800 (47.291 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 900...
# I1007 15:53:49.534727 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 900...
# INFO:tensorflow:Saving checkpoints for 900 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:53:49.535161 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 900 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 900...
# I1007 15:53:51.626922 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 900...
# INFO:tensorflow:global_step/sec: 2.10794
# I1007 15:53:52.099662 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.10794
# INFO:tensorflow:loss = 1.4863796, step = 900 (47.439 sec)
# I1007 15:53:52.100789 140371753760640 basic_session_run_hooks.py:260] loss = 1.4863796, step = 900 (47.439 sec)
# INFO:tensorflow:box_loss = 0.007406624, cls_loss = 0.5156821, det_loss = 0.88601327, step = 900 (47.440 sec)
# I1007 15:53:52.101574 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.007406624, cls_loss = 0.5156821, det_loss = 0.88601327, step = 900 (47.440 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1000...
# I1007 15:54:36.827588 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 1000...
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:54:36.827847 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 1000 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1000...
# I1007 15:54:38.911523 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 1000...
# INFO:tensorflow:global_step/sec: 2.11341
# I1007 15:54:39.416704 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.11341
# INFO:tensorflow:loss = 1.6258986, step = 1000 (47.317 sec)
# I1007 15:54:39.417883 140371753760640 basic_session_run_hooks.py:260] loss = 1.6258986, step = 1000 (47.317 sec)
# INFO:tensorflow:box_loss = 0.0068975827, cls_loss = 0.6808939, det_loss = 1.025773, step = 1000 (47.317 sec)
# I1007 15:54:39.418269 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.0068975827, cls_loss = 0.6808939, det_loss = 1.025773, step = 1000 (47.317 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1100...
# I1007 15:55:23.919395 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 1100...
# INFO:tensorflow:Saving checkpoints for 1100 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:55:23.919763 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 1100 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1100...
# I1007 15:55:25.996070 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 1100...
# INFO:tensorflow:global_step/sec: 2.1247
# I1007 15:55:26.482105 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.1247
# INFO:tensorflow:loss = 1.6289141, step = 1100 (47.066 sec)
# I1007 15:55:26.483482 140371753760640 basic_session_run_hooks.py:260] loss = 1.6289141, step = 1100 (47.066 sec)
# INFO:tensorflow:box_loss = 0.0071728807, cls_loss = 0.6703758, det_loss = 1.0290198, step = 1100 (47.065 sec)
# I1007 15:55:26.483728 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.0071728807, cls_loss = 0.6703758, det_loss = 1.0290198, step = 1100 (47.065 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1200...
# I1007 15:56:11.312604 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 1200...
# INFO:tensorflow:Saving checkpoints for 1200 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# I1007 15:56:11.312915 140371753760640 basic_session_run_hooks.py:618] Saving checkpoints for 1200 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 1200...
# I1007 15:56:13.371619 140371753760640 basic_session_run_hooks.py:626] Calling checkpoint listeners after saving checkpoint 1200...
# INFO:tensorflow:global_step/sec: 2.11246
# I1007 15:56:13.820343 140371753760640 basic_session_run_hooks.py:702] global_step/sec: 2.11246
# INFO:tensorflow:loss = 1.4163692, step = 1200 (47.338 sec)
# I1007 15:56:13.821617 140371753760640 basic_session_run_hooks.py:260] loss = 1.4163692, step = 1200 (47.338 sec)
# INFO:tensorflow:box_loss = 0.005120606, cls_loss = 0.5606718, det_loss = 0.8167021, step = 1200 (47.338 sec)
# I1007 15:56:13.821953 140371753760640 basic_session_run_hooks.py:260] box_loss = 0.005120606, cls_loss = 0.5606718, det_loss = 0.8167021, step = 1200 (47.338 sec)
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 1300...
# I1007 15:56:58.460085 140371753760640 basic_session_run_hooks.py:614] Calling checkpoint listeners before saving checkpoint 1300...
# INFO:tensorflow:Saving checkpoints for 1300 into /tmp/model_dir/efficientdet-d0-scratch/model.ckpt.
Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2020-10-07T15:58:07Z
# I1007 15:58:07.664594 140371753760640 evaluation.py:255] Starting evaluation at 2020-10-07T15:58:07Z
# INFO:tensorflow:Graph was finalized.
# I1007 15:58:08.889780 140371753760640 monitored_session.py:246] Graph was finalized.
# 2020-10-07 15:58:08.890573: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:58:08.891295: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 15:58:08.891357: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 15:58:08.891441: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 15:58:08.891481: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 15:58:08.891523: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 15:58:08.891567: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 15:58:08.891604: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 15:58:08.891642: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 15:58:08.891728: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:58:08.892357: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:58:08.892887: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-07 15:58:08.892946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-07 15:58:08.892966: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-07 15:58:08.892979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-07 15:58:08.893106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:58:08.893860: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 15:58:08.894433: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10630 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# INFO:tensorflow:Restoring parameters from /tmp/model_dir/efficientdet-d0-scratch/model.ckpt-1424
# I1007 15:58:08.895697 140371753760640 saver.py:1293] Restoring parameters from /tmp/model_dir/efficientdet-d0-scratch/model.ckpt-1424
# INFO:tensorflow:Running local_init_op.
# I1007 15:58:10.227065 140371753760640 session_manager.py:505] Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# I1007 15:58:10.294403 140371753760640 session_manager.py:508] Done running local_init_op.
# /content/automl/efficientdet/nms_np.py:193: RuntimeWarning: overflow encountered in multiply
#   areas = (x2 - x1 + 1) * (y2 - y1 + 1)
# /content/automl/efficientdet/nms_np.py:212: RuntimeWarning: overflow encountered in add
#   iou = inter / (dets[0, 5] + dets[1:, 5] - inter)
# /content/automl/efficientdet/nms_np.py:211: RuntimeWarning: overflow encountered in multiply
#   inter = w * h
# /content/automl/efficientdet/nms_np.py:212: RuntimeWarning: invalid value encountered in subtract
#   iou = inter / (dets[0, 5] + dets[1:, 5] - inter)
# INFO:tensorflow:Evaluation [142/1424]
# I1007 16:05:16.825502 140371753760640 evaluation.py:167] Evaluation [142/1424]
# INFO:tensorflow:Evaluation [284/1424]
# I1007 16:12:22.197961 140371753760640 evaluation.py:167] Evaluation [284/1424]
# INFO:tensorflow:Evaluation [426/1424]
# I1007 16:19:27.796354 140371753760640 evaluation.py:167] Evaluation [426/1424]
# INFO:tensorflow:Evaluation [568/1424]
# I1007 16:26:44.654276 140371753760640 evaluation.py:167] Evaluation [568/1424]
# INFO:tensorflow:Evaluation [710/1424]
# I1007 16:33:49.395547 140371753760640 evaluation.py:167] Evaluation [710/1424]
# INFO:tensorflow:Evaluation [852/1424]
# I1007 16:40:54.459700 140371753760640 evaluation.py:167] Evaluation [852/1424]
# creating index...
# index created!
# Loading and preparing results...
# Converting ndarray to lists...
# (396800, 7)
# 0/396800
# DONE (t=3.26s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=77.23s).
# Accumulating evaluation results...
# DONE (t=5.04s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.043
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.088
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.036
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.001
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.021
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.053
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.129
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.210
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.253
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.084
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.280
# INFO:tensorflow:Inference Time : 3075.10622s
# I1007 16:49:22.771016 140371753760640 evaluation.py:273] Inference Time : 3075.10622s
# INFO:tensorflow:Finished evaluation at 2020-10-07-16:49:22
# I1007 16:49:22.771329 140371753760640 evaluation.py:276] Finished evaluation at 2020-10-07-16:49:22
# INFO:tensorflow:Saving dict for global step 1424: AP = 0.042829633, AP50 = 0.08826412, AP75 = 0.03630688, APl = 0.052599963, APm = 0.021335471, APs = 0.0011458863, ARl = 0.28035137, ARm = 0.08440399, ARmax1 = 0.12850183, ARmax10 = 0.21008766, ARmax100 = 0.2531414, ARs = 0.00857583, box_loss = 0.007029019, cls_loss = 0.53632045, global_step = 1424, loss = 1.4869534
# I1007 16:49:22.771581 140371753760640 estimator.py:2063] Saving dict for global step 1424: AP = 0.042829633, AP50 = 0.08826412, AP75 = 0.03630688, APl = 0.052599963, APm = 0.021335471, APs = 0.0011458863, ARl = 0.28035137, ARm = 0.08440399, ARmax1 = 0.12850183, ARmax10 = 0.21008766, ARmax100 = 0.2531414, ARs = 0.00857583, box_loss = 0.007029019, cls_loss = 0.53632045, global_step = 1424, loss = 1.4869534
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1424: /tmp/model_dir/efficientdet-d0-scratch/model.ckpt-1424
# I1007 16:49:24.241331 140371753760640 estimator.py:2124] Saving 'checkpoint_path' summary for global step 1424: /tmp/model_dir/efficientdet-d0-scratch/model.ckpt-1424
# INFO:tensorflow:/tmp/model_dir/efficientdet-d0-scratch/archive/model.ckpt-1424 is not in all_model_checkpoint_paths. Manually adding it.
# I1007 16:49:24.291897 140371753760640 checkpoint_management.py:102] /tmp/model_dir/efficientdet-d0-scratch/archive/model.ckpt-1424 is not in all_model_checkpoint_paths. Manually adding it.
# I1007 16:49:24.292772 140371753760640 utils.py:464] Copying checkpoint /tmp/model_dir/efficientdet-d0-scratch/model.ckpt-1424 to /tmp/model_dir/efficientdet-d0-scratch/archive

# %% [markdown]
# ### Save trained model

# %%
# !ls /tmp/model_dir/efficientdet-d0-scratch/
# Out:
# archive
# best_objective.txt
# checkpoint
# config.yaml
# eval
# events.out.tfevents.1602085529.e9931d098751
# graph.pbtxt
# model.ckpt-1100.data-00000-of-00001
# model.ckpt-1100.index
# model.ckpt-1100.meta
# model.ckpt-1200.data-00000-of-00001
# model.ckpt-1200.index
# model.ckpt-1200.meta
# model.ckpt-1300.data-00000-of-00001
# model.ckpt-1300.index
# model.ckpt-1300.meta
# model.ckpt-1400.data-00000-of-00001
# model.ckpt-1400.index
# model.ckpt-1400.meta
# model.ckpt-1424.data-00000-of-00001
# model.ckpt-1424.index
# model.ckpt-1424.meta

# %%
savedmodeldir = '/content/savedmodel'
# !rm  -rf savedmodeldir
# !rm  -rf {savedmodeldir}
# !python model_inspect.py --runmode=saved_model --model_name=efficientdet-d0 \
  --hparams="num_classes=6,moving_average_decay=0"   \
  --ckpt_path=/tmp/model_dir/efficientdet-d0-scratch --saved_model_dir={savedmodeldir}
# Out:
# 2020-10-07 17:13:40.744184: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:13:42.932123: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-07 17:13:42.932364: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1eb8bc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 17:13:42.932412: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-07 17:13:42.935723: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-07 17:13:43.010349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.011245: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x1eb8a00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 17:13:43.011280: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-10-07 17:13:43.011502: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.012292: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 17:13:43.012349: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:13:43.014714: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 17:13:43.017086: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 17:13:43.017491: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 17:13:43.026158: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 17:13:43.027245: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 17:13:43.034480: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 17:13:43.034601: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.035356: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.036055: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-07 17:13:43.036112: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:13:43.508540: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-07 17:13:43.508644: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-07 17:13:43.508676: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-07 17:13:43.509085: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.510282: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.511186: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-07 17:13:43.511267: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10630 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# 2020-10-07 17:13:43.585303: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.585989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 17:13:43.586063: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:13:43.586119: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 17:13:43.586174: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 17:13:43.586230: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 17:13:43.586287: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 17:13:43.586339: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 17:13:43.586382: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 17:13:43.586501: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.587351: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:13:43.588015: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# W1007 17:13:56.559651 139862389782400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/saved_model/signature_def_utils_impl.py:201: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# WARNING:tensorflow:From /content/automl/efficientdet/inference.py:558: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W1007 17:13:59.249452 139862389782400 deprecation.py:323] From /content/automl/efficientdet/inference.py:558: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/convert_to_constants.py:854: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# W1007 17:13:59.249833 139862389782400 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/convert_to_constants.py:854: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`

# %% [markdown]
# ## Inference

# %%
# Prepare image
image_url =  'https://github.com/ibm-aur-nlp/PubLayNet/raw/master/examples/PMC3576793_00004.jpg'
img_path = '/content/img.png' 
# !wget {image_url} -O {img_path}
# Out:
# --2020-10-07 17:14:11--  https://github.com/ibm-aur-nlp/PubLayNet/raw/master/examples/PMC3576793_00004.jpg
# Resolving github.com (github.com)... 52.192.72.89
# Connecting to github.com (github.com)|52.192.72.89|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ibm-aur-nlp/PubLayNet/master/examples/PMC3576793_00004.jpg [following]
# --2020-10-07 17:14:11--  https://raw.githubusercontent.com/ibm-aur-nlp/PubLayNet/master/examples/PMC3576793_00004.jpg
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 327048 (319K) [image/jpeg]
# Saving to: ‘/content/img.png’
#
# /content/img.png    100%[===================>] 319.38K  --.-KB/s    in 0.06s
#
# 2020-10-07 17:14:12 (5.05 MB/s) - ‘/content/img.png’ saved [327048/327048]

# %%
# Prepare visualization settings
min_score_thresh = 0.35
max_boxes_to_draw = 200

# %%
# Then run saved_model_infer to do inference.
# Notably: batch_size, image_size must be the same as when it is exported.
serve_image_out = '/content/serve_image_out'
# !mkdir {serve_image_out}

# !python model_inspect.py --runmode=saved_model_infer \
  --saved_model_dir={savedmodeldir} \
  --model_name={MODEL}  --input_image={img_path}  \
  --output_image_dir={serve_image_out} \
  --min_score_thresh={min_score_thresh}  --max_boxes_to_draw={max_boxes_to_draw}
# Out:
# 2020-10-07 17:14:17.360807: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:14:19.510334: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-07 17:14:19.510631: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x14a4d80 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 17:14:19.510679: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-07 17:14:19.512883: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-07 17:14:19.583271: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:19.584240: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5e69500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-07 17:14:19.584275: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-10-07 17:14:19.584457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:19.585208: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla K80 computeCapability: 3.7
# coreClock: 0.8235GHz coreCount: 13 deviceMemorySize: 11.17GiB deviceMemoryBandwidth: 223.96GiB/s
# 2020-10-07 17:14:19.585266: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:14:19.587521: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-07 17:14:19.589376: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-07 17:14:19.589704: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-07 17:14:19.591743: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-07 17:14:19.592830: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-07 17:14:19.596870: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 17:14:19.596990: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:19.597770: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:19.598441: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-07 17:14:19.598497: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-07 17:14:20.065503: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-07 17:14:20.065580: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-07 17:14:20.065603: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-07 17:14:20.065823: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:20.066579: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-07 17:14:20.067222: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-07 17:14:20.067279: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10630 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# WARNING:tensorflow:From /content/automl/efficientdet/inference.py:546: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# W1007 17:14:20.068186 139646160447360 deprecation.py:323] From /content/automl/efficientdet/inference.py:546: load (from tensorflow.python.saved_model.loader_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.loader.load or tf.compat.v1.saved_model.load. There will be a new function for importing SavedModels in Tensorflow 2.0.
# all_files= ['/content/img.png']
# 2020-10-07 17:14:23.671611: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-07 17:14:24.476086: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# writing file to /content/serve_image_out/0.jpg
